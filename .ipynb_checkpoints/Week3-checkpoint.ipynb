# %% [markdown]
# # Exercise for the 3rd course week
#
# ## Ex 1 Classes
# 1. Create 3 classes: Student, DataSheet and Course
# 2. A student has a data_sheet and a data_sheet has multiple courses in particular order
# 3. Each course has name, classroom, teacher, ETCS and optional grade if course is taken.
# 4. In Student create __init__() so that a Student can be initiated with name, gender, data_sheet and image_url
# 5. In DataSheet create a method to get_grades_as_list()
# 6. In student create a method: get_avg_grade()
# 7. Create a function that can generate n number of students with random: name, gender, courses (from a fixed list of course names), grades, img_url
#    1. Let the function write the result to a csv file with format stud_name, course_name, teacher, ,gender, ects, classroom, grade, img_url
# 7. Read student data into a list of Students from a csv file (Each student can appear on multiple lines):
#    1. loop through the list and print each student with name, img_url and avg_grade.
#    2. sort the list by avg_grade
#    3. create a bar chart with student_name on x and avg_grade on y-axis
# 8. Make a method on Student class that can show progression of the study in % (add up ECTS from all passed courses divided by total of 150 total points (equivalent to 5 semesters))
# 9. Show a bar chart of distribution of study progression on x-axis and number of students in each category on y-axis. (e.g. make 10 categories from 0-100%)
#
# Extra: Make the Datasheet class iterable so that next(data_sheet) will return the next course in the list

# %% [markdown]
# ## Status Finished up to 10

# %% [markdown]
# ### 1: 6

# %%
class Student():
    
    def __init__(self, name, gender, dataSheet, image_url):
        self.name = name
        self.gender = gender
        self.dataSheet = dataSheet
        self.image_url = image_url
        self.avg_grade = self.get_avg_grade
        self.etcs = self.get_etcs
    
    def __str__(self):
        return '{name}, {gender}, {grades}, {avg_grades}'.format(
            name=self.name, gender=self.gender,
            grades=self.dataSheet.get_grades_as_list(),
            avg_grades=self.avg_grade())
    
    def get_avg_grade(self):
        grades = self.dataSheet.get_grades_as_list()
        length = len(grades)
        total = sum(grades)
        return total / length
    
    def get_etcs(self):
        etcs = (self.dataSheet.get_etcs_points() * 100) / 150
        rounded_etcs = round(etcs, 2)
        return rounded_etcs

# %%
class DataSheet():
    
    def __init__(self, courses=[]):
        self.courses = courses
        self.grades = []
        self.etcs = 0
    
    def get_grades_as_list(self):
        self.grades = []
        for course in self.courses:
            self.grades.append(course.optionalGrade)
        return self.grades
    
    def get_etcs_points(self):
        self.etcs = 0
        for course in self.courses:
            self.etcs += course.ETCS
        return self.etcs

# %%
class Course():
    
    def __init__(self, name, classroom, teacher, ETCS, optionalGrade):
        self.name = name
        self.classroom = classroom
        self.teacher = teacher
        self.ETCS = ETCS
        self.optionalGrade = optionalGrade

# %% [markdown]
# ### 7. Create a function that can generate n number of students with random: name, gender, courses (from a fixed list of course names), grades, img_url
#    1. Let the function write the result to a csv file with format stud_name, course_name, teacher, ,gender, ects, classroom, grade, img_url

# %%
import random
import csv

names = ['Abed', 'Jesper', 'Morten', 'Philip', 'Mo', 'Susanne', 'Lisa', 'jacob', 'Mette', 'Lars']
gender = ['male', 'female']
python = Course('python', 'H1', 'Bo', 14, 10)
java = Course('Java', 'H1', 'Jesper', 10, 7)
react = Course('React', 'H2', 'Karsten', 5, 12)
csharp = Course('C#', 'H3', 'Peter', 25, 10)

courselist = [python, java, react, csharp]

file_path = './Files/Students.csv'
fields = ['stud_name', 'gender', 'avg_grade', 'etcs_progress','img_url']
    
def randomStudent(n):
    listOfNumbers = range(n)
    listOfStudents = {number:Student(names[random.randrange(0,9)], random.choice(gender), createDataSheet(), random.randrange(0, 100)) for number in listOfNumbers}
    
    
    csv_list = []
    for value in listOfStudents.values():
        csv_list.append([value.name, value.gender, value.avg_grade(), value.etcs(), value.image_url])
    with open(file_path, 'w') as file:
        writer = csv.writer(file)
        writer.writerow(fields)
        writer.writerows(csv_list)
    return listOfStudents

def createDataSheet():
    numbers = range(random.randrange(1, 5))
    course_test_list = []
    for element in numbers:
        course_test_list.append(courselist[element - 1])
    dataSheet = DataSheet(course_test_list)
    return dataSheet

listofStudents_test = randomStudent(10)
for value in listofStudents_test.values():
    print(value)
# Out:
# Philip, female, [10, 10], 10.0
# Abed, female, [10, 10, 7, 12], 9.75
# Lisa, male, [10, 10], 10.0
# Lisa, male, [10, 10], 10.0
# Jesper, female, [10, 10, 7, 12], 9.75
# Lisa, female, [10], 10.0
# Mette, female, [10, 10], 10.0
# Philip, male, [10], 10.0
# Philip, male, [10, 10, 7], 9.0
# Jesper, male, [10], 10.0

# %% [markdown]
# ### 8. Read student data into a list of Students from a csv file (Each student can appear on multiple lines):
#    1. loop through the list and print each student with name, img_url and avg_grade.
#    2. sort the list by avg_grade
#    3. create a bar chart with student_name on x and avg_grade on y-axis

# %%
import csv

file_path = './Files/Students.csv'
students = []
names = []
avg_grades = []
with open(file_path, 'r') as f:
    content = f.readlines()
    
    for line in content:
        line_to_append = line.strip().split(',')
        students.append(line_to_append)
        print(line_to_append)

students.pop(0)
for student in students:
    names.append(student[0])
    avg_grades.append(student[3])
    
print(names)
print(avg_grades)
# %matplotlib notebook
import matplotlib.pyplot as plt
plt.bar(names, avg_grades)
# Out:
# ['stud_name', 'gender', 'avg_grade', 'etcs_progress', 'img_url']
# ['Philip', 'female', '10.0', '26.0', '14']
# ['Abed', 'female', '9.75', '36.0', '92']
# ['Lisa', 'male', '10.0', '26.0', '66']
# ['Lisa', 'male', '10.0', '26.0', '81']
# ['Jesper', 'female', '9.75', '36.0', '21']
# ['Lisa', 'female', '10.0', '16.67', '66']
# ['Mette', 'female', '10.0', '26.0', '45']
# ['Philip', 'male', '10.0', '16.67', '37']
# ['Philip', 'male', '9.0', '32.67', '52']
# ['Jesper', 'male', '10.0', '16.67', '34']
# ['Philip', 'Abed', 'Lisa', 'Lisa', 'Jesper', 'Lisa', 'Mette', 'Philip', 'Philip', 'Jesper']
# ['26.0', '36.0', '26.0', '26.0', '36.0', '16.67', '26.0', '16.67', '32.67', '16.67']
# <img src="data:image/png;base64,..." width="640">
# <BarContainer object of 10 artists>

# %% [markdown]
# ### 9. Make a method on Student class that can show progression of the study in % (add up ECTS from all passed courses divided by total of 150 total points (equivalent to 5 semesters))

# %%
import csv

file_path = './Files/Students.csv'
students = []
names = []
avg_grades = []
with open(file_path, 'r') as f:
    content = f.readlines()
    
    for line in content:
        line_to_append = line.strip().split(',')
        students.append(line_to_append)
        print(line_to_append)

students.pop(0)
for student in students:
    names.append(student[0])
    avg_grades.append(student[3])
# Out:
# ['stud_name', 'gender', 'avg_grade', 'etcs_progress', 'img_url']
# ['Philip', 'female', '10.0', '26.0', '14']
# ['Abed', 'female', '9.75', '36.0', '92']
# ['Lisa', 'male', '10.0', '26.0', '66']
# ['Lisa', 'male', '10.0', '26.0', '81']
# ['Jesper', 'female', '9.75', '36.0', '21']
# ['Lisa', 'female', '10.0', '16.67', '66']
# ['Mette', 'female', '10.0', '26.0', '45']
# ['Philip', 'male', '10.0', '16.67', '37']
# ['Philip', 'male', '9.0', '32.67', '52']
# ['Jesper', 'male', '10.0', '16.67', '34']

# %% [markdown]
# ## Ex 2 Exceptions (extra)
# 1. Create a function that can take a list of students and return the 3 students closest to completing their study.
# 2. If list is shorter than 3 raise your own custom exception (NotEnoughStudentsException)
# 3. Create another function that can create a csv file with 3 students closest to completion
#    1. If an exception is raised write an appropriate message to the file

# %% [markdown]
# ## Ex 3 Plotting (extra)
# 1. Create a function that can take a list of students and show a pie chart of how students are distributed in ECTS percentage categories (10%, 20%, ...)
# 2. create a function that can take a list of students and show how many students have taken each course (bar chart)
#    1. create a method on student that can return a list of courses
# 3. make the figure show males and females in different colors for each course (display 2 datasets in same figure)
